# %% [markdown]
# <a href="https://colab.research.google.com/github/leukschrauber/Assignments/blob/main/assignment_7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment
#
# *by Fabian Leuk (csba6437/12215478)*
#
# The following assignment consists again of a theoretical part (learning portfolio) and a practical part (assignment). The goal is to train a neural model for a recommendation system.
#
# Find any data set that can be used for a recommender system and try to train and validate a neural network for it.
#
# For this purpose I ask you to download a data set from the given lists and to use it for your program application.
#
# https://gist.github.com/entaroadun/1653794
# https://github.com/caserec/Datasets-for-Recommender-Systems
# https://grouplens.org/datasets/movielens/
# https://eigentaste.berkeley.edu/dataset/

# %% [markdown]
# ## Data Preparation
#
# I have chosen the Jester-Dataset, which comprises ratings of around 25.000 users for 100 jokes. The dataset can be downloaded [here](https://eigentaste.berkeley.edu/dataset/jester_dataset_1_1.zip), the corresponding jokes can be downloaded [here](https://eigentaste.berkeley.edu/dataset/jester_dataset_1_joke_texts.zip).
#
# * Data files are in .zip format, when unzipped, they are in Excel (.xls) format
# * Ratings are real values ranging from -10.00 to +10.00 (the value "99" corresponds to "null" = "not rated").
# * One row per user
# * The first column gives the number of jokes rated by that user. The next 100 columns give the ratings for jokes 01 - 100.
#
# I processed the data by extracting the joke texts from the HTML-Files using Regex-Matching and BeautifulSoup. Furthermore, I converted the joke ratings into long format as demanded by fastAI and scaled the ratings from being between -10 and 10 to be between 0 and 5.

# %%
# !pip install bs4
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
import os
import re
from bs4 import BeautifulSoup
from fastai.collab import *
from fastai.tabular.all import *
set_seed(42)

joke_text_files = '/content/gdrive/My Drive/SE_Digital_Organizations/jokes'
joke_ratings_file = '/content/gdrive/My Drive/SE_Digital_Organizations/jester-data-1.xls'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Mounted at /content/gdrive

# %%
# Function to extract joke text from html file and remove remaining HTML tags
def extract_joke_from_file(file_path):
    with open(file_path, "r") as file:
        html = file.read()

    pattern = r"<!--begin of joke -->(.*?)<!--end of joke -->"
    matches = re.findall(pattern, html, re.DOTALL)

    cleaned_jokes = []
    for joke in matches:
        soup = BeautifulSoup(joke, "html.parser")
        cleaned_joke = soup.get_text()
        cleaned_jokes.append(cleaned_joke)

    return cleaned_jokes

# Iterate over files in directory, sort by joke number and add to dataframe
html_files = [file_name for file_name in os.listdir(joke_text_files) if file_name.endswith(".html")]
html_files.sort(key=lambda x: int(re.search(r"\d+", x).group()))
jokes_list = []
for file_name in html_files:
    file_path = os.path.join(joke_text_files, file_name)
    jokes = extract_joke_from_file(file_path)

    if jokes:
        jokes_list.extend(jokes)

joke_text_df = pd.DataFrame({"joke_text": jokes_list})
joke_text_df = joke_text_df.reset_index().rename(columns={'index': 'joke_id'})
joke_text_df.head(5)
# Out:
#    joke_id  \
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#
#                                                                                                                                                                                                                                                                                                                                                                                                     joke_text
# 0                                                                                                                                                                                                                                    \nA man visits the doctor. The doctor says "I have bad news for you.You have\ncancer and Alzheimer's disease". \nThe man replies "Well,thank God I don't have cancer!"\n
# 1  \nThis couple had an excellent relationship going until one day he came home\nfrom work to find his girlfriend packing. He asked her why she was leaving him\nand she told him that she had heard awful things about him. \n\n"What could they possibly have said to make you move out?" \n\n"They told me that you were a pedophile." \n\nHe replied, "That's an awfully big word for a ten year old." \n
# 2                                                                                                                                                                                                                                                                                                               \nQ. What's 200 feet long and has 4 teeth? \n\nA. The front row at a Willie Nelson Concert.\n
# 3                                                                                                                                                                                                                                                                                        \nQ. What's the difference between a man and a toilet? \n\nA. A toilet doesn't follow you around after you use it.\n
# 4                                                                                                                                                                                                                                                                                                       \nQ.\tWhat's O. J. Simpson's Internet address? \nA.\tSlash, slash, backslash, slash, slash, escape.\n

# %%
# drop the rating count, make index the column user_id and scale ratings to be between zero and 5

joke_ratings = pd.read_excel(joke_ratings_file, header=None)
joke_ratings.columns=[str(i) for i in range(101)]

joke_ratings = joke_ratings.drop("0", axis=1)
joke_ratings = joke_ratings.reset_index().rename(columns={'index': 'user_id'})

def transform_column(column):
    if column.name != "user_id":
        return column.apply(lambda x: (x + 10) / 4)
    return column

joke_ratings = joke_ratings.apply(transform_column, axis=0)

print(joke_ratings.head(5))
# Out:
#    user_id       1        2        3        4       5       6       7       8  \
# 0        0   0.545   4.6975   0.0850   0.4600  0.6200  0.3750  0.0375  3.5425
# 1        1   3.520   2.4275   4.0900   3.5925  1.9050  0.0850  2.3175  1.1650
# 2        2  27.250  27.2500  27.2500  27.2500  4.7575  4.8175  4.7575  4.8175
# 3        3  27.250   4.5875  27.2500  27.2500  2.9500  4.5400  1.7950  4.0525
# 4        4   4.625   3.6525   1.4575   1.1525  2.8400  2.9000  4.2600  3.6525
#
#         9  ...       91       92       93       94       95       96       97  \
# 0   0.255  ...   3.2050  27.2500  27.2500  27.2500  27.2500  27.2500   1.0925
# 1   4.720  ...   3.2050   1.2625   2.4275   4.4650   2.4525   1.9650   3.2650
# 2  27.250  ...  27.2500  27.2500  27.2500   4.7700  27.2500  27.2500  27.2500
# 3  27.250  ...  27.2500  27.2500  27.2500   2.6325  27.2500  27.2500  27.2500
# 4   2.390  ...   3.7975   3.8950   3.5675   3.7975   3.9325   2.8875   3.2775
#
#         98     99      100
# 0  27.2500  27.25  27.2500
# 1   2.5850   1.42   2.7675
# 2  27.2500  27.25  27.2500
# 3  27.2500  27.25  27.2500
# 4   4.1375   2.95   2.9000
#
# [5 rows x 101 columns]

# %%
# convert from wide to long format
melted_joke_ratings = pd.melt(joke_ratings, id_vars='user_id', value_vars=joke_ratings.columns[1:], var_name='number', value_name='rating')
melted_joke_ratings = melted_joke_ratings[melted_joke_ratings['rating'] != 27.25]
melted_joke_ratings = melted_joke_ratings.copy()
melted_joke_ratings.head(5)
# Out:
#    user_id number  rating
# 0        0      1  0.5450
# 1        1      1  3.5200
# 4        4      1  4.6250
# 5        5      1  0.9575
# 7        7      1  4.2100

# %%
dls = CollabDataLoaders.from_df(melted_joke_ratings, item_name='number', user_name="user_id", bs=128)

# %% [markdown]
# ## Training
#
# For training, I used fastAI's collab_learner API. I trained a ordinary collaborative filtering model and a neural network with the following hyperparameters:
#
# *   batch size: 128
# *   latent factors: determined by fastAI => 50
# *   epochs: 10
# *   learning rate: 5e-4
# *   weight decay: 0.1
#
# The hyperparameter choice turned out to be quite tricky, but finally I found these parameters which were decreasing the training and validation losses consistently and provided reasonable results overall.
#
# Although training losses were smaller for the neural network, the ordinary collaborative filtering model achieved lower losses on the validation data set.
#
# Because training time was around 30 minutes, I saved the models to my Google Drive for later retrieval.

# %% [markdown]
# ### Using Collab Learner

# %%
ordinary_learn = collab_learner(dls, y_range=(0.0, 5.5))
ordinary_learn.fit_one_cycle(10, 5e-4, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.473742</td>
#       <td>1.456311</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.176519</td>
#       <td>1.171204</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.126006</td>
#       <td>1.126780</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.074324</td>
#       <td>1.097894</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.055906</td>
#       <td>1.074965</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.029559</td>
#       <td>1.058813</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.971448</td>
#       <td>1.049513</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.944129</td>
#       <td>1.044559</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.910618</td>
#       <td>1.042669</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.925971</td>
#       <td>1.042407</td>
#       <td>01:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Using Neural Network

# %%
nn_learn = collab_learner(dls, use_nn=True, y_range=(0, 5.5))
nn_learn.fit_one_cycle(10, 5e-4, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [6/10 12:28&lt;08:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.232545</td>
#       <td>1.210195</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.153208</td>
#       <td>1.147422</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.109861</td>
#       <td>1.105820</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.099963</td>
#       <td>1.088661</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.054629</td>
#       <td>1.078682</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.006162</td>
#       <td>1.068304</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='1219' class='' max='11315' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.77% [1219/11315 00:13&lt;01:51 0.9273]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.232545</td>
#       <td>1.210195</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.153208</td>
#       <td>1.147422</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.109861</td>
#       <td>1.105820</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.099963</td>
#       <td>1.088661</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.054629</td>
#       <td>1.078682</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.006162</td>
#       <td>1.068304</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.975808</td>
#       <td>1.060126</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.901285</td>
#       <td>1.058520</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.832088</td>
#       <td>1.070963</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.813799</td>
#       <td>1.076950</td>
#       <td>02:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
nn_learn.export('/content/gdrive/My Drive/SE_Digital_Organizations/neural_network/model.pkl')
ordinary_learn.export('/content/gdrive/My Drive/SE_Digital_Organizations/ordinary_learner/model.pkl')

# %% [markdown]
# ## Interpretation
#
# Let's see what are the best jokes by finding the jokes with the highest bias term.

# %%
loaded = load_learner('/content/gdrive/My Drive/SE_Digital_Organizations/ordinary_learner/model.pkl')

# %%
loaded.model
# Out:
# EmbeddingDotBias(
#   (u_weight): Embedding(24984, 50)
#   (i_weight): Embedding(101, 50)
#   (u_bias): Embedding(24984, 1)
#   (i_bias): Embedding(101, 1)
# )

# %%
best_joke_ids = loaded.model.i_bias.weight.squeeze().argsort(descending=True)[:5]
print(best_joke_ids)
filtered_df = joke_text_df[joke_text_df['joke_id'].isin(best_joke_ids.tolist())]
for index, row in filtered_df.iterrows():
    print(row['joke_id'])
    print(row['joke_text'])
# Out:
# tensor([47, 89, 31, 21, 27])
# 21
#
# A duck walks into a pharmacy and asks for a condom. The pharmacist says
# "Would you like me to stick that on your bill?"
# The duck says:
# "What kind of duck do you think I am!"
#
# 27
#
# A mechanical, electrical and a software engineer from Microsoft were
# driving through the desert when the car broke down. The mechanical
# engineer said "It seems to be a problem with the fuel injection system,
# why don't we pop the hood and I'll take a look at it." To which the
# electrical engineer replied, "No I think it's just a loose ground wire,
# I'll get out and take a look." Then, the Microsoft engineer jumps in.
# "No, no, no. If we just close up all the windows, get out, wait a few
# minutes, get back in, and then reopen the windows everything will work
# fine."
#
# 31
#
# A man arrives at the gates of heaven. St. Peter asks, "Religion?"
# The man says, "Methodist." St. Peter looks down his list, and says,
# "Go to room 24, but be very quiet as you pass room 8."
#
# Another man arrives at the gates of heaven. "Religion?"
# "Baptist." "Go to room 18, but be very quiet as you pass room 8."
#
# A third man arrives at the gates. "Religion?" "Jewish."
# "Go to room 11, but be very quiet as you pass room 8."
# The man says, "I can understand there being different rooms for different religions, but why
# must I be quiet when I pass room 8?" St. Peter tells him, "Well the Catholics are in room 8,
# and they think they're the only ones here.
#
# 47
#
# The graduate with a Science degree asks, "Why does it work?"
# The graduate with an Engineering degree asks, "How does it work?"
# The graduate with an Accounting degree Asks, "How much will it cost?"
# The graduate with a  Liberal Arts degree asks, "Do you want fries
# with  that?"
#
# 89
#
# Q: How many programmers does it take to change a lightbulb?
#
# A: NONE!   That's a hardware problem....

# %% [markdown]
# ## Recommending jokes
#
# I proceed to recommend joke for users that are part of the dataset in the following steps:
#
#
#
# 1.   Calculate the cosine similarity between the embedding of a particular user and the embeddings of all other users => ~25.000 Similarities
# 2.   For each joke, take the sumproduct of the similarities and the respective ratings for a user => SUMPRODUCT(~25.000 Similarities, 100 joke ratings) => 1 summated rating
# 3.   Divide the previous SUMPRODUCT by the sum of all similarities to get a weighted average rating.
# 4.   Identify the top 10 rated jokes for a user
# 5.   If a user did not rate one of these jokes, recommend it to him.

# %%
def recommend_joke_to_user(user_id):
  user_factors = loaded.model.u_weight.weight
  distances = nn.CosineSimilarity(dim=1)(user_factors[user_id], user_factors)
  distances = distances[:-1]
  joke_ratings_without_user = joke_ratings.drop(["user_id"], axis=1)
  joke_ratings_without_user = torch.from_numpy(joke_ratings_without_user.values)
  replaced_tensor = torch.where(joke_ratings_without_user > 5.1, torch.tensor(0), joke_ratings_without_user)
  ratings = replaced_tensor * distances[:, np.newaxis]
  summated_ratings = torch.sum(ratings, dim=0)
  weighted_ratings = summated_ratings/distances.sum()
  values, joke_indices = torch.topk(weighted_ratings, 10)

  recommendation_given = False;

  for joke_index in joke_indices.tolist():
      user_may_have_rated = melted_joke_ratings[(melted_joke_ratings["user_id"] == user_id) & (melted_joke_ratings["number"] == str(joke_index))]
      if(len(user_may_have_rated) > 0):
        print("User " + str(user_id) + " already rated joke with the id " + str(joke_index))
        continue;
      else:
        print("Recommend joke with id " + str(joke_index) + " to user " + str(user_id))
        joke_df = joke_text_df[(joke_text_df["joke_id"] == joke_index)]
        for index, row in joke_df.iterrows():
          print(row['joke_id'])
          print(row['joke_text'])
          recommendation_given = True
          break;

  if(not recommendation_given):
    print("Top jokes for user " + str(user_id) + " already rated.")

# %%
for i in range(100):
  recommend_joke_to_user(i)
# Out:
# User 0 already rated joke with the id 49
# User 0 already rated joke with the id 26
# User 0 already rated joke with the id 35
# User 0 already rated joke with the id 31
# User 0 already rated joke with the id 28
# User 0 already rated joke with the id 34
# User 0 already rated joke with the id 65
# User 0 already rated joke with the id 52
# User 0 already rated joke with the id 48
# User 0 already rated joke with the id 61
# Top jokes for user 0 already rated.
# User 1 already rated joke with the id 49
# User 1 already rated joke with the id 35
# User 1 already rated joke with the id 26
# User 1 already rated joke with the id 31
# User 1 already rated joke with the id 34
# User 1 already rated joke with the id 68
# User 1 already rated joke with the id 52
# User 1 already rated joke with the id 67
# User 1 already rated joke with the id 28
# User 1 already rated joke with the id 48
# Top jokes for user 1 already rated.
# User 2 already rated joke with the id 49
# User 2 already rated joke with the id 35
# User 2 already rated joke with the id 26
# Recommend joke with id 34 to user 2
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 2 already rated joke with the id 31
# User 2 already rated joke with the id 68
# Recommend joke with id 52 to user 2
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 2 already rated joke with the id 28
# User 2 already rated joke with the id 61
# Recommend joke with id 67 to user 2
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 3 already rated joke with the id 49
# User 3 already rated joke with the id 35
# User 3 already rated joke with the id 31
# User 3 already rated joke with the id 26
# User 3 already rated joke with the id 34
# User 3 already rated joke with the id 61
# User 3 already rated joke with the id 52
# User 3 already rated joke with the id 28
# User 3 already rated joke with the id 48
# Recommend joke with id 67 to user 3
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 4 already rated joke with the id 49
# User 4 already rated joke with the id 35
# User 4 already rated joke with the id 26
# User 4 already rated joke with the id 31
# User 4 already rated joke with the id 34
# User 4 already rated joke with the id 61
# User 4 already rated joke with the id 28
# User 4 already rated joke with the id 52
# User 4 already rated joke with the id 68
# User 4 already rated joke with the id 48
# Top jokes for user 4 already rated.
# User 5 already rated joke with the id 49
# User 5 already rated joke with the id 35
# User 5 already rated joke with the id 31
# User 5 already rated joke with the id 26
# User 5 already rated joke with the id 34
# User 5 already rated joke with the id 61
# User 5 already rated joke with the id 28
# User 5 already rated joke with the id 52
# User 5 already rated joke with the id 48
# User 5 already rated joke with the id 68
# Top jokes for user 5 already rated.
# User 6 already rated joke with the id 49
# User 6 already rated joke with the id 35
# User 6 already rated joke with the id 31
# User 6 already rated joke with the id 26
# Recommend joke with id 34 to user 6
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 6 already rated joke with the id 61
# User 6 already rated joke with the id 52
# User 6 already rated joke with the id 28
# User 6 already rated joke with the id 48
# Recommend joke with id 67 to user 6
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 7 already rated joke with the id 49
# User 7 already rated joke with the id 35
# User 7 already rated joke with the id 31
# User 7 already rated joke with the id 26
# User 7 already rated joke with the id 34
# User 7 already rated joke with the id 61
# User 7 already rated joke with the id 28
# User 7 already rated joke with the id 52
# User 7 already rated joke with the id 48
# User 7 already rated joke with the id 67
# Top jokes for user 7 already rated.
# User 8 already rated joke with the id 49
# User 8 already rated joke with the id 35
# User 8 already rated joke with the id 31
# User 8 already rated joke with the id 26
# User 8 already rated joke with the id 34
# User 8 already rated joke with the id 52
# User 8 already rated joke with the id 61
# User 8 already rated joke with the id 28
# User 8 already rated joke with the id 48
# User 8 already rated joke with the id 68
# Top jokes for user 8 already rated.
# User 9 already rated joke with the id 49
# User 9 already rated joke with the id 31
# User 9 already rated joke with the id 26
# User 9 already rated joke with the id 34
# User 9 already rated joke with the id 53
# User 9 already rated joke with the id 61
# User 9 already rated joke with the id 28
# User 9 already rated joke with the id 35
# User 9 already rated joke with the id 48
# User 9 already rated joke with the id 52
# Top jokes for user 9 already rated.
# User 10 already rated joke with the id 49
# User 10 already rated joke with the id 35
# User 10 already rated joke with the id 31
# Recommend joke with id 26 to user 10
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 10
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# Recommend joke with id 61 to user 10
# 61
#
# A group of  managers were given the assignment to measure the
# height of a flagpole. So they go out to the flagpole with ladders
# and tape measures, and they're falling off the ladders, dropping
# the tape measures - the whole thing is just a mess.
# An engineer comes along and sees what they're trying to do,
# walks over, pulls the flagpole out of the ground, lays it flat,
# measures it from end to end, gives the measurement to one of the
# managers and walks away.
# After the engineer has gone, one manager turns to another and
# laughs. "Isn't that just like an engineer, we're looking for the
# height and he gives us the length."
#
# Recommend joke with id 52 to user 10
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# Recommend joke with id 28 to user 10
# 28
#
# An old Scotsmen is sitting with a younger Scottish gentleman and says the boy.
# "Ah, lad look out that window. You see that stone wall there, I built it with
# me own bare hands, placed every stone meself.  But do they call me MacGregor the
# wall builder? No!
#
# He Takes a few sips of his beer then says, "Aye, and look out on that lake and
# eye that beautiful pier. I built it meself, laid every board and hammered each
# nail but do they call me MacGregor the pier builder? No!
#
# He continues..."And lad, you see that road? That too I build with me own bare
# hands. Laid every inch of pavement meself, but do they call MacGregor the road
# builder? No!"
#
# Again he returns to his beer for a few sips, then says,
# "Agh, but you screw one sheep..."
#
# User 10 already rated joke with the id 48
# Recommend joke with id 67 to user 10
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 11 already rated joke with the id 49
# User 11 already rated joke with the id 35
# User 11 already rated joke with the id 31
# User 11 already rated joke with the id 26
# User 11 already rated joke with the id 34
# User 11 already rated joke with the id 61
# User 11 already rated joke with the id 28
# User 11 already rated joke with the id 52
# User 11 already rated joke with the id 48
# User 11 already rated joke with the id 67
# Top jokes for user 11 already rated.
# User 12 already rated joke with the id 49
# User 12 already rated joke with the id 35
# User 12 already rated joke with the id 31
# Recommend joke with id 26 to user 12
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 12
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 12 already rated joke with the id 61
# Recommend joke with id 52 to user 12
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 12 already rated joke with the id 28
# User 12 already rated joke with the id 68
# User 12 already rated joke with the id 48
# User 13 already rated joke with the id 49
# User 13 already rated joke with the id 35
# User 13 already rated joke with the id 31
# User 13 already rated joke with the id 26
# User 13 already rated joke with the id 34
# User 13 already rated joke with the id 61
# User 13 already rated joke with the id 28
# User 13 already rated joke with the id 52
# User 13 already rated joke with the id 48
# User 13 already rated joke with the id 67
# Top jokes for user 13 already rated.
# User 14 already rated joke with the id 49
# User 14 already rated joke with the id 35
# User 14 already rated joke with the id 31
# User 14 already rated joke with the id 26
# User 14 already rated joke with the id 34
# User 14 already rated joke with the id 61
# User 14 already rated joke with the id 52
# User 14 already rated joke with the id 28
# User 14 already rated joke with the id 48
# User 14 already rated joke with the id 68
# Top jokes for user 14 already rated.
# User 15 already rated joke with the id 49
# User 15 already rated joke with the id 35
# User 15 already rated joke with the id 31
# User 15 already rated joke with the id 26
# User 15 already rated joke with the id 34
# User 15 already rated joke with the id 61
# User 15 already rated joke with the id 28
# User 15 already rated joke with the id 52
# User 15 already rated joke with the id 48
# User 15 already rated joke with the id 67
# Top jokes for user 15 already rated.
# User 16 already rated joke with the id 49
# User 16 already rated joke with the id 35
# User 16 already rated joke with the id 31
# User 16 already rated joke with the id 26
# User 16 already rated joke with the id 61
# User 16 already rated joke with the id 34
# User 16 already rated joke with the id 28
# Recommend joke with id 52 to user 16
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 16 already rated joke with the id 48
# User 16 already rated joke with the id 53
# User 17 already rated joke with the id 49
# User 17 already rated joke with the id 35
# User 17 already rated joke with the id 31
# User 17 already rated joke with the id 26
# User 17 already rated joke with the id 34
# User 17 already rated joke with the id 61
# User 17 already rated joke with the id 52
# User 17 already rated joke with the id 28
# User 17 already rated joke with the id 48
# User 17 already rated joke with the id 67
# Top jokes for user 17 already rated.
# User 18 already rated joke with the id 49
# User 18 already rated joke with the id 35
# User 18 already rated joke with the id 31
# User 18 already rated joke with the id 26
# Recommend joke with id 34 to user 18
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# Recommend joke with id 52 to user 18
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 18 already rated joke with the id 61
# User 18 already rated joke with the id 28
# User 18 already rated joke with the id 48
# User 18 already rated joke with the id 68
# User 19 already rated joke with the id 49
# User 19 already rated joke with the id 35
# User 19 already rated joke with the id 31
# User 19 already rated joke with the id 26
# User 19 already rated joke with the id 34
# User 19 already rated joke with the id 52
# User 19 already rated joke with the id 28
# User 19 already rated joke with the id 61
# User 19 already rated joke with the id 68
# User 19 already rated joke with the id 48
# Top jokes for user 19 already rated.
# User 20 already rated joke with the id 49
# User 20 already rated joke with the id 35
# User 20 already rated joke with the id 31
# Recommend joke with id 26 to user 20
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# User 20 already rated joke with the id 61
# Recommend joke with id 34 to user 20
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 20 already rated joke with the id 28
# Recommend joke with id 52 to user 20
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 20 already rated joke with the id 48
# User 20 already rated joke with the id 53
# User 21 already rated joke with the id 49
# User 21 already rated joke with the id 35
# User 21 already rated joke with the id 26
# User 21 already rated joke with the id 31
# User 21 already rated joke with the id 34
# Recommend joke with id 52 to user 21
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 21 already rated joke with the id 28
# User 21 already rated joke with the id 61
# User 21 already rated joke with the id 68
# Recommend joke with id 67 to user 21
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 22 already rated joke with the id 49
# User 22 already rated joke with the id 35
# User 22 already rated joke with the id 26
# User 22 already rated joke with the id 31
# User 22 already rated joke with the id 52
# User 22 already rated joke with the id 28
# User 22 already rated joke with the id 61
# User 22 already rated joke with the id 34
# User 22 already rated joke with the id 67
# User 22 already rated joke with the id 68
# Top jokes for user 22 already rated.
# User 23 already rated joke with the id 49
# User 23 already rated joke with the id 35
# User 23 already rated joke with the id 31
# User 23 already rated joke with the id 26
# User 23 already rated joke with the id 34
# User 23 already rated joke with the id 61
# User 23 already rated joke with the id 28
# User 23 already rated joke with the id 52
# User 23 already rated joke with the id 48
# User 23 already rated joke with the id 67
# Top jokes for user 23 already rated.
# User 24 already rated joke with the id 49
# User 24 already rated joke with the id 35
# User 24 already rated joke with the id 31
# User 24 already rated joke with the id 26
# User 24 already rated joke with the id 34
# User 24 already rated joke with the id 61
# User 24 already rated joke with the id 28
# User 24 already rated joke with the id 52
# User 24 already rated joke with the id 48
# User 24 already rated joke with the id 67
# Top jokes for user 24 already rated.
# User 25 already rated joke with the id 49
# User 25 already rated joke with the id 35
# User 25 already rated joke with the id 31
# User 25 already rated joke with the id 26
# User 25 already rated joke with the id 34
# User 25 already rated joke with the id 61
# User 25 already rated joke with the id 52
# User 25 already rated joke with the id 28
# User 25 already rated joke with the id 48
# User 25 already rated joke with the id 67
# Top jokes for user 25 already rated.
# User 26 already rated joke with the id 49
# User 26 already rated joke with the id 35
# User 26 already rated joke with the id 31
# User 26 already rated joke with the id 26
# User 26 already rated joke with the id 34
# User 26 already rated joke with the id 61
# User 26 already rated joke with the id 28
# Recommend joke with id 52 to user 26
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 26 already rated joke with the id 48
# User 26 already rated joke with the id 68
# User 27 already rated joke with the id 49
# User 27 already rated joke with the id 35
# User 27 already rated joke with the id 31
# User 27 already rated joke with the id 26
# User 27 already rated joke with the id 34
# User 27 already rated joke with the id 61
# User 27 already rated joke with the id 28
# User 27 already rated joke with the id 52
# User 27 already rated joke with the id 48
# User 27 already rated joke with the id 67
# Top jokes for user 27 already rated.
# User 28 already rated joke with the id 49
# User 28 already rated joke with the id 35
# User 28 already rated joke with the id 31
# User 28 already rated joke with the id 26
# User 28 already rated joke with the id 34
# User 28 already rated joke with the id 61
# User 28 already rated joke with the id 28
# User 28 already rated joke with the id 52
# User 28 already rated joke with the id 48
# User 28 already rated joke with the id 68
# Top jokes for user 28 already rated.
# User 29 already rated joke with the id 49
# User 29 already rated joke with the id 35
# User 29 already rated joke with the id 31
# User 29 already rated joke with the id 26
# User 29 already rated joke with the id 34
# Recommend joke with id 61 to user 29
# 61
#
# A group of  managers were given the assignment to measure the
# height of a flagpole. So they go out to the flagpole with ladders
# and tape measures, and they're falling off the ladders, dropping
# the tape measures - the whole thing is just a mess.
# An engineer comes along and sees what they're trying to do,
# walks over, pulls the flagpole out of the ground, lays it flat,
# measures it from end to end, gives the measurement to one of the
# managers and walks away.
# After the engineer has gone, one manager turns to another and
# laughs. "Isn't that just like an engineer, we're looking for the
# height and he gives us the length."
#
# User 29 already rated joke with the id 28
# User 29 already rated joke with the id 52
# User 29 already rated joke with the id 48
# Recommend joke with id 67 to user 29
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 30 already rated joke with the id 49
# User 30 already rated joke with the id 35
# User 30 already rated joke with the id 31
# User 30 already rated joke with the id 26
# User 30 already rated joke with the id 34
# User 30 already rated joke with the id 61
# User 30 already rated joke with the id 52
# User 30 already rated joke with the id 28
# User 30 already rated joke with the id 48
# User 30 already rated joke with the id 68
# Top jokes for user 30 already rated.
# User 31 already rated joke with the id 49
# User 31 already rated joke with the id 35
# User 31 already rated joke with the id 26
# User 31 already rated joke with the id 31
# User 31 already rated joke with the id 34
# User 31 already rated joke with the id 61
# User 31 already rated joke with the id 52
# User 31 already rated joke with the id 28
# User 31 already rated joke with the id 48
# Recommend joke with id 67 to user 31
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 32 already rated joke with the id 49
# User 32 already rated joke with the id 35
# User 32 already rated joke with the id 31
# User 32 already rated joke with the id 26
# User 32 already rated joke with the id 34
# User 32 already rated joke with the id 52
# User 32 already rated joke with the id 61
# User 32 already rated joke with the id 28
# User 32 already rated joke with the id 48
# User 32 already rated joke with the id 68
# Top jokes for user 32 already rated.
# User 33 already rated joke with the id 49
# User 33 already rated joke with the id 35
# User 33 already rated joke with the id 31
# Recommend joke with id 26 to user 33
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 33
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 33 already rated joke with the id 61
# Recommend joke with id 52 to user 33
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 33 already rated joke with the id 28
# User 33 already rated joke with the id 48
# User 33 already rated joke with the id 68
# User 34 already rated joke with the id 49
# User 34 already rated joke with the id 35
# User 34 already rated joke with the id 31
# User 34 already rated joke with the id 26
# User 34 already rated joke with the id 34
# User 34 already rated joke with the id 52
# User 34 already rated joke with the id 28
# User 34 already rated joke with the id 61
# User 34 already rated joke with the id 48
# User 34 already rated joke with the id 68
# Top jokes for user 34 already rated.
# User 35 already rated joke with the id 49
# User 35 already rated joke with the id 35
# User 35 already rated joke with the id 31
# Recommend joke with id 26 to user 35
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 35
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 35 already rated joke with the id 61
# Recommend joke with id 52 to user 35
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 35 already rated joke with the id 28
# User 35 already rated joke with the id 48
# Recommend joke with id 67 to user 35
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 36 already rated joke with the id 49
# User 36 already rated joke with the id 35
# User 36 already rated joke with the id 31
# User 36 already rated joke with the id 26
# User 36 already rated joke with the id 34
# User 36 already rated joke with the id 61
# User 36 already rated joke with the id 28
# User 36 already rated joke with the id 52
# User 36 already rated joke with the id 48
# User 36 already rated joke with the id 67
# Top jokes for user 36 already rated.
# User 37 already rated joke with the id 49
# User 37 already rated joke with the id 35
# User 37 already rated joke with the id 31
# Recommend joke with id 26 to user 37
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 37
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 37 already rated joke with the id 61
# User 37 already rated joke with the id 52
# User 37 already rated joke with the id 28
# User 37 already rated joke with the id 48
# User 37 already rated joke with the id 68
# User 38 already rated joke with the id 49
# User 38 already rated joke with the id 35
# User 38 already rated joke with the id 31
# User 38 already rated joke with the id 26
# User 38 already rated joke with the id 34
# User 38 already rated joke with the id 61
# User 38 already rated joke with the id 28
# User 38 already rated joke with the id 52
# User 38 already rated joke with the id 48
# User 38 already rated joke with the id 67
# Top jokes for user 38 already rated.
# User 39 already rated joke with the id 49
# User 39 already rated joke with the id 35
# User 39 already rated joke with the id 31
# User 39 already rated joke with the id 26
# User 39 already rated joke with the id 34
# User 39 already rated joke with the id 52
# User 39 already rated joke with the id 61
# User 39 already rated joke with the id 28
# User 39 already rated joke with the id 68
# User 39 already rated joke with the id 48
# Top jokes for user 39 already rated.
# User 40 already rated joke with the id 49
# User 40 already rated joke with the id 35
# User 40 already rated joke with the id 31
# User 40 already rated joke with the id 34
# User 40 already rated joke with the id 26
# User 40 already rated joke with the id 61
# User 40 already rated joke with the id 28
# User 40 already rated joke with the id 52
# User 40 already rated joke with the id 53
# User 40 already rated joke with the id 48
# Top jokes for user 40 already rated.
# User 41 already rated joke with the id 49
# User 41 already rated joke with the id 35
# User 41 already rated joke with the id 31
# User 41 already rated joke with the id 26
# User 41 already rated joke with the id 61
# User 41 already rated joke with the id 34
# User 41 already rated joke with the id 28
# Recommend joke with id 52 to user 41
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 41 already rated joke with the id 48
# User 41 already rated joke with the id 53
# User 42 already rated joke with the id 49
# User 42 already rated joke with the id 35
# User 42 already rated joke with the id 31
# User 42 already rated joke with the id 26
# Recommend joke with id 34 to user 42
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# ...
# were before we met, but now it's my fault!"
#
#
# User 82 already rated joke with the id 49
# User 82 already rated joke with the id 35
# User 82 already rated joke with the id 31
# User 82 already rated joke with the id 26
# User 82 already rated joke with the id 34
# User 82 already rated joke with the id 52
# User 82 already rated joke with the id 28
# User 82 already rated joke with the id 68
# User 82 already rated joke with the id 61
# User 82 already rated joke with the id 67
# Top jokes for user 82 already rated.
# User 83 already rated joke with the id 49
# User 83 already rated joke with the id 35
# User 83 already rated joke with the id 31
# User 83 already rated joke with the id 26
# User 83 already rated joke with the id 34
# User 83 already rated joke with the id 52
# User 83 already rated joke with the id 28
# User 83 already rated joke with the id 61
# User 83 already rated joke with the id 68
# User 83 already rated joke with the id 48
# Top jokes for user 83 already rated.
# User 84 already rated joke with the id 49
# User 84 already rated joke with the id 35
# User 84 already rated joke with the id 31
# Recommend joke with id 26 to user 84
# 26
#
# Clinton returns from a vacation in Arkansas and walks down  the
# steps of Air Force One with two pigs under his arms.  At the bottom
# of the steps, he says  to the honor guardsman, "These are genuine
# Arkansas Razor-Back Hogs.  I got this one for Chelsea and this one for
# Hillary."
#
# The guardsman replies, "Nice trade, Sir."
#
# Recommend joke with id 34 to user 84
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# Recommend joke with id 52 to user 84
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 84 already rated joke with the id 28
# User 84 already rated joke with the id 61
# User 84 already rated joke with the id 48
# Recommend joke with id 67 to user 84
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 85 already rated joke with the id 49
# User 85 already rated joke with the id 35
# User 85 already rated joke with the id 31
# User 85 already rated joke with the id 26
# User 85 already rated joke with the id 34
# User 85 already rated joke with the id 61
# User 85 already rated joke with the id 52
# User 85 already rated joke with the id 28
# User 85 already rated joke with the id 48
# User 85 already rated joke with the id 67
# Top jokes for user 85 already rated.
# User 86 already rated joke with the id 49
# User 86 already rated joke with the id 35
# User 86 already rated joke with the id 31
# User 86 already rated joke with the id 26
# User 86 already rated joke with the id 34
# User 86 already rated joke with the id 61
# User 86 already rated joke with the id 28
# User 86 already rated joke with the id 52
# User 86 already rated joke with the id 48
# User 86 already rated joke with the id 67
# Top jokes for user 86 already rated.
# User 87 already rated joke with the id 49
# User 87 already rated joke with the id 35
# User 87 already rated joke with the id 31
# User 87 already rated joke with the id 26
# User 87 already rated joke with the id 34
# User 87 already rated joke with the id 52
# User 87 already rated joke with the id 61
# User 87 already rated joke with the id 28
# User 87 already rated joke with the id 48
# User 87 already rated joke with the id 68
# Top jokes for user 87 already rated.
# User 88 already rated joke with the id 49
# User 88 already rated joke with the id 35
# User 88 already rated joke with the id 31
# User 88 already rated joke with the id 26
# User 88 already rated joke with the id 34
# User 88 already rated joke with the id 61
# User 88 already rated joke with the id 28
# User 88 already rated joke with the id 52
# User 88 already rated joke with the id 48
# User 88 already rated joke with the id 53
# Top jokes for user 88 already rated.
# User 89 already rated joke with the id 49
# User 89 already rated joke with the id 35
# User 89 already rated joke with the id 31
# User 89 already rated joke with the id 26
# User 89 already rated joke with the id 34
# User 89 already rated joke with the id 52
# User 89 already rated joke with the id 61
# User 89 already rated joke with the id 28
# User 89 already rated joke with the id 48
# User 89 already rated joke with the id 67
# Top jokes for user 89 already rated.
# User 90 already rated joke with the id 49
# User 90 already rated joke with the id 35
# User 90 already rated joke with the id 31
# User 90 already rated joke with the id 26
# User 90 already rated joke with the id 34
# User 90 already rated joke with the id 52
# User 90 already rated joke with the id 61
# User 90 already rated joke with the id 28
# User 90 already rated joke with the id 48
# User 90 already rated joke with the id 67
# Top jokes for user 90 already rated.
# User 91 already rated joke with the id 49
# User 91 already rated joke with the id 35
# User 91 already rated joke with the id 31
# User 91 already rated joke with the id 26
# User 91 already rated joke with the id 34
# User 91 already rated joke with the id 28
# User 91 already rated joke with the id 52
# User 91 already rated joke with the id 61
# User 91 already rated joke with the id 48
# User 91 already rated joke with the id 67
# Top jokes for user 91 already rated.
# User 92 already rated joke with the id 49
# User 92 already rated joke with the id 35
# User 92 already rated joke with the id 31
# User 92 already rated joke with the id 26
# User 92 already rated joke with the id 34
# User 92 already rated joke with the id 61
# User 92 already rated joke with the id 28
# Recommend joke with id 52 to user 92
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 92 already rated joke with the id 48
# User 92 already rated joke with the id 53
# User 93 already rated joke with the id 49
# User 93 already rated joke with the id 35
# User 93 already rated joke with the id 31
# User 93 already rated joke with the id 26
# User 93 already rated joke with the id 34
# User 93 already rated joke with the id 61
# User 93 already rated joke with the id 52
# User 93 already rated joke with the id 28
# User 93 already rated joke with the id 68
# User 93 already rated joke with the id 48
# Top jokes for user 93 already rated.
# User 94 already rated joke with the id 49
# User 94 already rated joke with the id 35
# User 94 already rated joke with the id 31
# User 94 already rated joke with the id 26
# User 94 already rated joke with the id 34
# User 94 already rated joke with the id 28
# User 94 already rated joke with the id 61
# User 94 already rated joke with the id 52
# User 94 already rated joke with the id 68
# User 94 already rated joke with the id 48
# Top jokes for user 94 already rated.
# User 95 already rated joke with the id 49
# User 95 already rated joke with the id 35
# User 95 already rated joke with the id 31
# User 95 already rated joke with the id 26
# User 95 already rated joke with the id 34
# User 95 already rated joke with the id 52
# User 95 already rated joke with the id 61
# User 95 already rated joke with the id 28
# User 95 already rated joke with the id 48
# User 95 already rated joke with the id 67
# Top jokes for user 95 already rated.
# User 96 already rated joke with the id 49
# User 96 already rated joke with the id 35
# User 96 already rated joke with the id 26
# User 96 already rated joke with the id 31
# User 96 already rated joke with the id 34
# User 96 already rated joke with the id 61
# User 96 already rated joke with the id 52
# User 96 already rated joke with the id 28
# User 96 already rated joke with the id 68
# User 96 already rated joke with the id 48
# Top jokes for user 96 already rated.
# User 97 already rated joke with the id 49
# User 97 already rated joke with the id 35
# User 97 already rated joke with the id 31
# User 97 already rated joke with the id 26
# User 97 already rated joke with the id 61
# Recommend joke with id 34 to user 97
# 34
#
# An explorer in the deepest Amazon suddenly finds himself surrounded
# by a bloodthirsty group of natives. Upon surveying the situation, he
# says quietly to himself, "Oh God, I'm screwed."
#
# The sky darkens and a voice booms out, "No, you are NOT
# screwed. Pick up that stone at your feet and bash in the head of the
# chief standing in front of you."
#
# So with the stone he bashes the life out of the chief. Standing above
# the lifeless body, breathing heavily looking at 100 angry natives...
#
# The voice booms out again, "Okay ..... NOW you're screwed."
#
# User 97 already rated joke with the id 52
# User 97 already rated joke with the id 28
# User 97 already rated joke with the id 48
# Recommend joke with id 67 to user 97
# 67
#
# A man piloting a hot air balloon discovers he has wandered off course and
# is hopelessly lost. He descends to a lower altitude and locates a man
# down on the ground. He lowers the balloon further and shouts "Excuse me,
# can you tell me where I am?"
#
# The man below says: "Yes, you're in a hot air balloon, about 30 feet
# above this field."
#
# "You must work in Information Technology," says the balloonist.
#
# "Yes I do," replies the man. "And how did you know that?"
#
# "Well," says the balloonist, "what you told me is technically correct,
# but of no use to anyone."
#
# The man below says, "You must work in management."
#
# "I do," replies the balloonist, "how did you know?"
#
# "Well," says the man, "you don't know where you are, or where you're
# going, but you expect my immediate help. You're in the same position you
# were before we met, but now it's my fault!"
#
#
# User 98 already rated joke with the id 53
# User 98 already rated joke with the id 30
# User 98 already rated joke with the id 61
# User 98 already rated joke with the id 49
# User 98 already rated joke with the id 31
# User 98 already rated joke with the id 28
# User 98 already rated joke with the id 34
# User 98 already rated joke with the id 48
# User 98 already rated joke with the id 47
# User 98 already rated joke with the id 26
# Top jokes for user 98 already rated.
# User 99 already rated joke with the id 49
# User 99 already rated joke with the id 35
# User 99 already rated joke with the id 31
# User 99 already rated joke with the id 26
# User 99 already rated joke with the id 34
# Recommend joke with id 52 to user 99
# 52
#
# One Sunday morning William burst into the living room and said,
# "Dad! Mom! I have some great news for you! I am getting married
# to the most beautiful girl in town. She lives a block away and
# her name is Susan."
# After dinner, William's dad took him aside. "Son, I have to talk
# with you. Your mother and I have been married 30 years.. She's a
# wonderful wife but she has never offered much excitement in the
# bedroom, so I used to fool around with women a lot. Susan is
# actually your half-sister, and I'm afraid you can't marry her."
# William was heart-broken. After eight months he eventually
# started dating girls again. A year later he came home and very
# proudly announced, "Dianne said yes! We're getting married in
# June."
# Again his father insisted on another private conversation and
# broke the sad news. "Dianne is your half-sister too, William. I'm
# awfully sorry about this."
# William was furious! He finally decided to go to his mother with
# the news.
# "Dad has done so much harm.. I guess I'm never going to get
# married,"  he complained. "Every time I fall in love, Dad tells
# me the girl is my half-sister."
# His mother just shook her head. "Don't pay any attention to what
# he says, dear. He's not really your father."
#
# User 99 already rated joke with the id 28
# Recommend joke with id 61 to user 99
# 61
#
# A group of  managers were given the assignment to measure the
# height of a flagpole. So they go out to the flagpole with ladders
# and tape measures, and they're falling off the ladders, dropping
# the tape measures - the whole thing is just a mess.
# An engineer comes along and sees what they're trying to do,
# walks over, pulls the flagpole out of the ground, lays it flat,
# measures it from end to end, gives the measurement to one of the
# managers and walks away.
# After the engineer has gone, one manager turns to another and
# laughs. "Isn't that just like an engineer, we're looking for the
# height and he gives us the length."
#
# Recommend joke with id 48 to user 99
# 48
#
# Three engineering students were gathered together discussing the
# possible designers of the human body.
# One said, "It was a mechanical engineer. Just look at all the joints."
# Another said, "No, it was an electrical engineer.  The nervous systems many thousands of electrical
# connections."
# The last said, "Actually it was a civil engineer. Who else would run a toxic waste pipeline through a recreational area?"
#
# User 99 already rated joke with the id 67
